# %%
from src.plot import dice_scores, probs_hist, logits_hist, \
    entropy_segment_per_center, ece_reliability, dice_vs_entropy, \
    uncertainty_by_condition
path_csvs = '/home/franco/Code/wmh-mc-seg/notebooks/training_Utrecht_MEEP_9381'

# %% [markdown]
# ## Whole-image metrics
# Dice

# %%
dice_scores('utrecht', path_csvs)

# %%
entropy_segment_per_center('utrecht', path_csvs)
# Out:
# Segment type: pred
# utrecht: {'35': 0.6852214963607483, '29': 0.6859270017678603, '25': 0.6871583624851338, '33': 0.6877871100492415}
# singapore: {'67': 0.6909423893790232, '63': 0.6908618923598281, '50': 0.6897896742868768, '68': 0.6838369813606184}
# amsterdam: {'106': 0.6881326700889339, '116': 0.6882152654412995, '137': 0.6894327806651492, '103': 0.6862199847566522}
# Segment type: gt
# utrecht: {'35': 0.6485174091308119, '29': 0.6804366045738961, '25': 0.6820989339458073, '33': 0.6415375322818246}
# singapore: {'67': 0.3713639266802738, '63': 0.4671563610721492, '50': 0.5451460925178753, '68': 0.2732034603288117}
# amsterdam: {'106': 0.4765410215085563, '116': 0.4175843340349214, '137': 0.38489924424658756, '103': 0.3304492627350569}
# Segment type: bMask
# utrecht: {'35': 0.19061630997101858, '29': 0.2314591667948895, '25': 0.275122836287302, '33': 0.1985293600934146}
# singapore: {'67': 0.17153355886162203, '63': 0.2009483348185327, '50': 0.1837761544182268, '68': 0.14202565099958567}
# amsterdam: {'106': 0.28262426574226873, '116': 0.2642319008874379, '137': 0.28018626561004556, '103': 0.26320553379758227}

# %% [markdown]
# Entropy

# %%
uncertainty_by_condition('utrecht', path_csvs)

# %% [markdown]
# ### Dice vs entropy

# %%
dice_vs_entropy('utrecht', path_csvs)

# %% [markdown]
# ## Class-wise metrics
# Here the voxels are separated according to their class (0 or 1) and the metrics are computed for each class separately.
# - Probabilities histogram from the softmax output
# - Absolute logit values histogram
# - Reliability diagram + ECE
#
# ### Probabilities histogram

# %%
probs_hist('utrecht', path_csvs)
# Out:
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/35/pred_wmh_softmax_training_Utrecht_MEEP_9381_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/29/pred_wmh_softmax_training_Utrecht_MEEP_9381_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/25/pred_wmh_softmax_training_Utrecht_MEEP_9381_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/33/pred_wmh_softmax_training_Utrecht_MEEP_9381_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/67/pred_wmh_softmax_training_Utrecht_MEEP_9381_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/63/pred_wmh_softmax_training_Utrecht_MEEP_9381_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/50/pred_wmh_softmax_training_Utrecht_MEEP_9381_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/68/pred_wmh_softmax_training_Utrecht_MEEP_9381_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/106/pred_wmh_softmax_training_Utrecht_MEEP_9381_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/116/pred_wmh_softmax_training_Utrecht_MEEP_9381_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/137/pred_wmh_softmax_training_Utrecht_MEEP_9381_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/103/pred_wmh_softmax_training_Utrecht_MEEP_9381_best.nii.gz...

# %% [markdown]
# ### Absolute logit values histogram

# %%
logits_hist('utrecht', path_csvs)
# Out:
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/35/pred_logits_training_Utrecht_MEEP_9381_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/29/pred_logits_training_Utrecht_MEEP_9381_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/25/pred_logits_training_Utrecht_MEEP_9381_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/33/pred_logits_training_Utrecht_MEEP_9381_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/67/pred_logits_training_Utrecht_MEEP_9381_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/63/pred_logits_training_Utrecht_MEEP_9381_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/50/pred_logits_training_Utrecht_MEEP_9381_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/68/pred_logits_training_Utrecht_MEEP_9381_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/106/pred_logits_training_Utrecht_MEEP_9381_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/116/pred_logits_training_Utrecht_MEEP_9381_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/137/pred_logits_training_Utrecht_MEEP_9381_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/103/pred_logits_training_Utrecht_MEEP_9381_best.nii.gz...

# %% [markdown]
# ### ECE and reliability diagrams

# %%
ece_reliability('utrecht', path_csvs)
