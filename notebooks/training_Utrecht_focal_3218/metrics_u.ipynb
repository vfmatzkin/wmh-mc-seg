# %%
from src.plot import dice_scores, probs_hist, logits_hist, entropy_segment, \
    ece_reliability, dice_vs_entropy
path_csvs = '/home/franco/Code/wmh-mc-seg/notebooks/training_Utrecht_focal_3218'

# %% [markdown]
# ## Whole-image metrics
# Dice

# %%
dice_scores('utrecht', path_csvs)

# %% [markdown]
# Entropy

# %%
entropy_segment('utrecht', path_csvs)
# Out:
# Center: utrecht
# 35: {'pred': [0.11659126480882427], 'gt': [0.09761401127669286]}
# 29: {'pred': [0.08250656151586074], 'gt': [0.06911138598972158]}
# 25: {'pred': [0.10315744782047352], 'gt': [0.07458376548812594]}
# 33: {'pred': [0.17241437274410892], 'gt': [0.1245432783406242]}
# Center: singapore
# 67: {'pred': [0.21899333336100082], 'gt': [0.048099869701060456]}
# 63: {'pred': [0.15752833756900972], 'gt': [0.06436785518925199]}
# 50: {'pred': [0.13741417390894117], 'gt': [0.09188147385025586]}
# 68: {'pred': [0.23654685087330415], 'gt': [0.023613194128787495]}
# Center: amsterdam
# 106: {'pred': [0.18184231439448245], 'gt': [0.03837573754057399]}
# 116: {'pred': [0.13475408941207803], 'gt': [0.04045921889560464]}
# 137: {'pred': [0.18600082149261624], 'gt': [0.04810135440217444]}
# 103: {'pred': [0.1478887911645444], 'gt': [0.03898428764612297]}

# %% [markdown]
# ### Dice vs entropy

# %%
dice_vs_entropy('utrecht', path_csvs)

# %% [markdown]
# ## Class-wise metrics
# Here the voxels are separated according to their class (0 or 1) and the metrics are computed for each class separately.
# - Probabilities histogram from the softmax output
# - Absolute logit values histogram
# - Reliability diagram + ECE
#
# ### Probabilities histogram

# %%
probs_hist('utrecht', path_csvs)
# Out:
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/35/pred_wmh_softmax_training_Utrecht_focal_3218_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/29/pred_wmh_softmax_training_Utrecht_focal_3218_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/25/pred_wmh_softmax_training_Utrecht_focal_3218_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/33/pred_wmh_softmax_training_Utrecht_focal_3218_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/67/pred_wmh_softmax_training_Utrecht_focal_3218_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/63/pred_wmh_softmax_training_Utrecht_focal_3218_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/50/pred_wmh_softmax_training_Utrecht_focal_3218_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/68/pred_wmh_softmax_training_Utrecht_focal_3218_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/106/pred_wmh_softmax_training_Utrecht_focal_3218_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/116/pred_wmh_softmax_training_Utrecht_focal_3218_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/137/pred_wmh_softmax_training_Utrecht_focal_3218_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/103/pred_wmh_softmax_training_Utrecht_focal_3218_best.nii.gz...

# %% [markdown]
# ### Absolute logit values histogram

# %%
logits_hist('utrecht', path_csvs)
# Out:
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/35/pred_logits_training_Utrecht_focal_3218_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/29/pred_logits_training_Utrecht_focal_3218_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/25/pred_logits_training_Utrecht_focal_3218_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/33/pred_logits_training_Utrecht_focal_3218_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/67/pred_logits_training_Utrecht_focal_3218_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/63/pred_logits_training_Utrecht_focal_3218_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/50/pred_logits_training_Utrecht_focal_3218_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/68/pred_logits_training_Utrecht_focal_3218_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/106/pred_logits_training_Utrecht_focal_3218_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/116/pred_logits_training_Utrecht_focal_3218_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/137/pred_logits_training_Utrecht_focal_3218_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/103/pred_logits_training_Utrecht_focal_3218_best.nii.gz...

# %% [markdown]
# ### ECE and reliability diagrams

# %%
ece_reliability('utrecht', path_csvs)
