# %%
from src.plot import dice_scores, probs_hist, logits_hist, entropy_segment, \
    ece_reliability, dice_vs_entropy
path_csvs = '/home/franco/Code/wmh-mc-seg/notebooks/training_Utrecht_dice_1335'

# %% [markdown]
# ## Whole-image metrics
# Dice

# %%
dice_scores('utrecht', path_csvs)

# %% [markdown]
# Entropy

# %%
entropy_segment('utrecht', path_csvs)
# Out:
# Center: utrecht
# 35: {'pred': [0.10395657158650638], 'gt': [0.04612096725713134]}
# 29: {'pred': [0.06757102576913417], 'gt': [0.05043340784565872]}
# 25: {'pred': [0.08353041698164589], 'gt': [0.047731459050596774]}
# 33: {'pred': [0.15062437996861902], 'gt': [0.07307415202892587]}
# Center: singapore
# 67: {'pred': [0.17458052269884206], 'gt': [0.03566661279164656]}
# 63: {'pred': [0.16322308688674683], 'gt': [0.04451419472889615]}
# 50: {'pred': [0.1421565945586847], 'gt': [0.06749455767914216]}
# 68: {'pred': [0.16541477416921224], 'gt': [0.03656782168166664]}
# Center: amsterdam
# 106: {'pred': [0.18521404857906162], 'gt': [0.038462791017664054]}
# 116: {'pred': [0.14897006997460302], 'gt': [0.03746586921583948]}
# 137: {'pred': [0.2057821634185069], 'gt': [0.059859007771609914]}
# 103: {'pred': [0.157632834316776], 'gt': [0.039596862999284825]}

# %% [markdown]
# ### Dice vs entropy

# %%
dice_vs_entropy('utrecht', path_csvs)

# %% [markdown]
# ## Class-wise metrics
# Here the voxels are separated according to their class (0 or 1) and the metrics are computed for each class separately.
# - Probabilities histogram from the softmax output
# - Absolute logit values histogram
# - Reliability diagram + ECE
#
# ### Probabilities histogram

# %%
probs_hist('utrecht', path_csvs)
# Out:
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/35/pred_wmh_softmax_training_Utrecht_dice_1335_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/29/pred_wmh_softmax_training_Utrecht_dice_1335_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/25/pred_wmh_softmax_training_Utrecht_dice_1335_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/33/pred_wmh_softmax_training_Utrecht_dice_1335_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/67/pred_wmh_softmax_training_Utrecht_dice_1335_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/63/pred_wmh_softmax_training_Utrecht_dice_1335_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/50/pred_wmh_softmax_training_Utrecht_dice_1335_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/68/pred_wmh_softmax_training_Utrecht_dice_1335_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/106/pred_wmh_softmax_training_Utrecht_dice_1335_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/116/pred_wmh_softmax_training_Utrecht_dice_1335_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/137/pred_wmh_softmax_training_Utrecht_dice_1335_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/103/pred_wmh_softmax_training_Utrecht_dice_1335_best.nii.gz...

# %% [markdown]
# ### Absolute logit values histogram

# %%
logits_hist('utrecht', path_csvs)
# Out:
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/35/pred_logits_training_Utrecht_dice_1335_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/29/pred_logits_training_Utrecht_dice_1335_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/25/pred_logits_training_Utrecht_dice_1335_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/33/pred_logits_training_Utrecht_dice_1335_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/67/pred_logits_training_Utrecht_dice_1335_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/63/pred_logits_training_Utrecht_dice_1335_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/50/pred_logits_training_Utrecht_dice_1335_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/68/pred_logits_training_Utrecht_dice_1335_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/106/pred_logits_training_Utrecht_dice_1335_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/116/pred_logits_training_Utrecht_dice_1335_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/137/pred_logits_training_Utrecht_dice_1335_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/103/pred_logits_training_Utrecht_dice_1335_best.nii.gz...

# %% [markdown]
# ### ECE and reliability diagrams

# %%
ece_reliability('utrecht', path_csvs)
