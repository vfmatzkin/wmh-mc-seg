# %%
from plot import dice_scores, probs_hist, logits_hist, ece_reliability, \
    entropy_segment

# %% [markdown]
# ## Whole-image metrics
# Dice

# %%
dice_scores('singapore')

# %% [markdown]
# Entropy

# %%
entropy_segment('singapore')
# Out:
# Center: utrecht
# 35: {'pred': [4.007333185232471], 'gt': [6.9353704460151055]}
# 29: {'pred': [6.432940092739174], 'gt': [9.685455913108095]}
# 25: {'pred': [6.745236349484363], 'gt': [9.076008659180896]}
# 33: {'pred': [6.628041376179535], 'gt': [7.266827347520591]}
# Center: singapore
# 67: {'pred': [9.233079858945672], 'gt': [9.371438292318503]}
# 63: {'pred': [9.398561160701128], 'gt': [9.389573832170907]}
# 50: {'pred': [8.718172930028727], 'gt': [9.054972284742485]}
# 68: {'pred': [9.416459832284598], 'gt': [9.412464556066316]}
# Center: amsterdam
# 106: {'pred': [6.647688373563329], 'gt': [6.75809450442773]}
# 116: {'pred': [6.3578422665081], 'gt': [6.418364935936215]}
# 137: {'pred': [7.083387847625296], 'gt': [7.844632644464686]}
# 103: {'pred': [7.81237820598861], 'gt': [8.77353938355816]}

# %% [markdown]
# ## Class-wise metrics
# Here the voxels are separated according to their class (0 or 1) and the metrics are computed for each class separately.
# - Probabilities histogram from the softmax output
# - Absolute logit values histogram
# - Reliability diagram + ECE
#
# ### Probabilities histogram

# %%
probs_hist('singapore')
# Out:
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/35/pred_wmh_softmax_training_Singapore_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/29/pred_wmh_softmax_training_Singapore_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/25/pred_wmh_softmax_training_Singapore_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/33/pred_wmh_softmax_training_Singapore_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/67/pred_wmh_softmax_training_Singapore_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/63/pred_wmh_softmax_training_Singapore_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/50/pred_wmh_softmax_training_Singapore_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/68/pred_wmh_softmax_training_Singapore_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/106/pred_wmh_softmax_training_Singapore_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/116/pred_wmh_softmax_training_Singapore_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/137/pred_wmh_softmax_training_Singapore_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/103/pred_wmh_softmax_training_Singapore_best.nii.gz...

# %% [markdown]
# ### Absolute logit values histogram

# %%
logits_hist('singapore')
# Out:
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/35/pred_logits_training_Singapore_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/29/pred_logits_training_Singapore_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/25/pred_logits_training_Singapore_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/33/pred_logits_training_Singapore_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/67/pred_logits_training_Singapore_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/63/pred_logits_training_Singapore_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/50/pred_logits_training_Singapore_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/68/pred_logits_training_Singapore_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/106/pred_logits_training_Singapore_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/116/pred_logits_training_Singapore_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/137/pred_logits_training_Singapore_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/103/pred_logits_training_Singapore_best.nii.gz...

# %% [markdown]
# ### ECE and reliability diagrams

# %%
ece_reliability('singapore')
