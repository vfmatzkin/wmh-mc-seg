# %%
from src.plot import dice_scores, probs_hist, logits_hist, entropy_segment, \
    ece_reliability, dice_vs_entropy
path_csvs = '/home/franco/Code/wmh-mc-seg/notebooks/training_Utrecht_ce_7704'

# %% [markdown]
# ## Whole-image metrics
# Dice

# %%
dice_scores('utrecht', path_csvs)

# %% [markdown]
# Entropy

# %%
entropy_segment('utrecht', path_csvs)
# Out:
# Center: utrecht
# 35: {'pred': [0.1297680930423986], 'gt': [0.10385333186438069]}
# 29: {'pred': [0.08261914444237302], 'gt': [0.07440699350014533]}
# 25: {'pred': [0.10821282765543074], 'gt': [0.099670691702165]}
# 33: {'pred': [0.14657706133611964], 'gt': [0.12547793172551386]}
# Center: singapore
# 67: {'pred': [0.18040538581982357], 'gt': [0.08676294161546447]}
# 63: {'pred': [0.1825221821410346], 'gt': [0.0661101441742565]}
# 50: {'pred': [0.15560292050454297], 'gt': [0.1030371578416339]}
# 68: {'pred': [0.1954396565608753], 'gt': [0.05293879778253099]}
# Center: amsterdam
# 106: {'pred': [0.18473679601314624], 'gt': [0.03299234081346111]}
# 116: {'pred': [0.15693636437097738], 'gt': [0.04936601169281683]}
# 137: {'pred': [0.18106866256232104], 'gt': [0.042112964762698046]}
# 103: {'pred': [0.18315917749058655], 'gt': [0.046082470910090434]}

# %% [markdown]
# ### Dice vs entropy

# %%
dice_vs_entropy('utrecht', path_csvs)

# %% [markdown]
# ## Class-wise metrics
# Here the voxels are separated according to their class (0 or 1) and the metrics are computed for each class separately.
# - Probabilities histogram from the softmax output
# - Absolute logit values histogram
# - Reliability diagram + ECE
#
# ### Probabilities histogram

# %%
probs_hist('utrecht', path_csvs)
# Out:
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/35/pred_wmh_softmax_training_Utrecht_ce_7704_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/29/pred_wmh_softmax_training_Utrecht_ce_7704_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/25/pred_wmh_softmax_training_Utrecht_ce_7704_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/33/pred_wmh_softmax_training_Utrecht_ce_7704_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/67/pred_wmh_softmax_training_Utrecht_ce_7704_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/63/pred_wmh_softmax_training_Utrecht_ce_7704_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/50/pred_wmh_softmax_training_Utrecht_ce_7704_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/68/pred_wmh_softmax_training_Utrecht_ce_7704_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/106/pred_wmh_softmax_training_Utrecht_ce_7704_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/116/pred_wmh_softmax_training_Utrecht_ce_7704_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/137/pred_wmh_softmax_training_Utrecht_ce_7704_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/103/pred_wmh_softmax_training_Utrecht_ce_7704_best.nii.gz...

# %% [markdown]
# ### Absolute logit values histogram

# %%
logits_hist('utrecht', path_csvs)
# Out:
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/35/pred_logits_training_Utrecht_ce_7704_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/29/pred_logits_training_Utrecht_ce_7704_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/25/pred_logits_training_Utrecht_ce_7704_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/33/pred_logits_training_Utrecht_ce_7704_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/67/pred_logits_training_Utrecht_ce_7704_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/63/pred_logits_training_Utrecht_ce_7704_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/50/pred_logits_training_Utrecht_ce_7704_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/68/pred_logits_training_Utrecht_ce_7704_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/106/pred_logits_training_Utrecht_ce_7704_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/116/pred_logits_training_Utrecht_ce_7704_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/137/pred_logits_training_Utrecht_ce_7704_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/103/pred_logits_training_Utrecht_ce_7704_best.nii.gz...

# %% [markdown]
# ### ECE and reliability diagrams

# %%
ece_reliability('utrecht', path_csvs)
