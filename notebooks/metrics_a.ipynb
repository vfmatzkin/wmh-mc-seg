# %%
from plot import dice_scores, probs_hist, logits_hist, ece_reliability, \
    entropy_segment

# %% [markdown]
# ## Whole-image metrics
# Dice

# %%
dice_scores('amsterdam')

# %% [markdown]
# Entropy

# %%
entropy_segment('amsterdam')
# Out:
# Center: utrecht
# 35: {'pred': [5.411646051855035], 'gt': [6.9353704460151055]}
# 29: {'pred': [3.8286413964890946], 'gt': [9.685455913108095]}
# 25: {'pred': [4.59511985013459], 'gt': [9.076008659180896]}
# 33: {'pred': [0.0], 'gt': [7.266827347520591]}
# Center: singapore
# 67: {'pred': [8.173293438966226], 'gt': [9.371438292318503]}
# 63: {'pred': [8.395703293828527], 'gt': [9.389573832170907]}
# 50: {'pred': [6.791221462726186], 'gt': [9.054972284742485]}
# 68: {'pred': [8.402455513945814], 'gt': [9.412464556066316]}
# Center: amsterdam
# 106: {'pred': [6.901737206656576], 'gt': [6.75809450442773]}
# 116: {'pred': [6.797940412974929], 'gt': [6.418364935936215]}
# 137: {'pred': [7.344719054149673], 'gt': [7.844632644464686]}
# 103: {'pred': [8.58988587680968], 'gt': [8.77353938355816]}

# %% [markdown]
# ## Class-wise metrics
# Here the voxels are separated according to their class (0 or 1) and the metrics are computed for each class separately.
# - Probabilities histogram from the softmax output
# - Absolute logit values histogram
# - Reliability diagram + ECE
#
# ### Probabilities histogram

# %%
probs_hist('amsterdam')
# Out:
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/35/pred_wmh_softmax_training_Amsterdam_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/29/pred_wmh_softmax_training_Amsterdam_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/25/pred_wmh_softmax_training_Amsterdam_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/33/pred_wmh_softmax_training_Amsterdam_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/67/pred_wmh_softmax_training_Amsterdam_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/63/pred_wmh_softmax_training_Amsterdam_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/50/pred_wmh_softmax_training_Amsterdam_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/68/pred_wmh_softmax_training_Amsterdam_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/106/pred_wmh_softmax_training_Amsterdam_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/116/pred_wmh_softmax_training_Amsterdam_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/137/pred_wmh_softmax_training_Amsterdam_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/103/pred_wmh_softmax_training_Amsterdam_best.nii.gz...

# %% [markdown]
# ### Absolute logit values histogram

# %%
logits_hist('amsterdam')
# Out:
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/35/pred_logits_training_Amsterdam_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/29/pred_logits_training_Amsterdam_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/25/pred_logits_training_Amsterdam_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Utrecht/33/pred_logits_training_Amsterdam_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/67/pred_logits_training_Amsterdam_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/63/pred_logits_training_Amsterdam_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/50/pred_logits_training_Amsterdam_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Singapore/68/pred_logits_training_Amsterdam_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/106/pred_logits_training_Amsterdam_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/116/pred_logits_training_Amsterdam_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/137/pred_logits_training_Amsterdam_best.nii.gz...
# Processing /home/franco/Code/datasets/wmh/training/Amsterdam/GE3T/103/pred_logits_training_Amsterdam_best.nii.gz...

# %% [markdown]
# ### ECE and reliability diagrams

# %%
ece_reliability('amsterdam')
